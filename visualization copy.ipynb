# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import numpy as np
from typing import  List
from models.hivt import HiVT
import os

def plot_single_vehicle(
    sample_past_trajectory: np.ndarray,  # (20, 2)
    sample_groundtruth: np.ndarray,  # (20, 2) 
    sample_forecasted_trajectories: List[np.ndarray],  # List[(30, 2)]
    sample_city_name: str, 
    ls: str):

    ## Plot history
    obs_len = sample_past_trajectory.shape[0]
    pred_len = sample_groundtruth.shape[0]

    plt.plot(
        sample_past_trajectory[:, 0],
        sample_past_trajectory[:, 1],
        color="#ECA154",
        label="Past Trajectory",
        alpha=1,
        linewidth=2.2,
        zorder=15,
        ls = '-'
    )

    ## Plot future
    plt.plot(
        sample_groundtruth[:, 0],
        sample_groundtruth[:, 1],
        color="#d33e4c",
        label="Ground Truth",
        alpha=1,
        linewidth=2.2,
        zorder=20,
        ls = "--"
    )

    ## Plot prediction
    for j in range(len(sample_forecasted_trajectories)):
        plt.plot(
            sample_forecasted_trajectories[j][:, 0],
            sample_forecasted_trajectories[j][:, 1],
            color="#007672",
            label="Forecasted Trajectory",
            alpha=1,
            linewidth=2.0,
            zorder=15,
            ls = "--"
        )
        
        # Plot the end marker for forcasted trajectories
        plt.arrow(
            sample_forecasted_trajectories[j][-2, 0], 
            sample_forecasted_trajectories[j][-2, 1],
            sample_forecasted_trajectories[j][-1, 0] - sample_forecasted_trajectories[j][-2, 0],
            sample_forecasted_trajectories[j][-1, 1] - sample_forecasted_trajectories[j][-2, 1],
            color="#007672",
            label="Forecasted Trajectory",
            alpha=1,
            linewidth=2.5,
            zorder=15,
            head_width=1.1,
        )
    
    # Plot the end marker for history
    plt.arrow(
            sample_past_trajectory[-2, 0], 
            sample_past_trajectory[-2, 1],
            sample_past_trajectory[-1, 0] - sample_past_trajectory[-2, 0],
            sample_past_trajectory[-1, 1] - sample_past_trajectory[-2, 1],
            color="#ECA154",
            label="Past Trajectory",
            alpha=1,
            linewidth=2.5,
            zorder=25,
            head_width=1.0,
        )

    ## Plot the end marker for future
    plt.arrow(
            sample_groundtruth[-2, 0], 
            sample_groundtruth[-2, 1],
            sample_groundtruth[-1, 0] - sample_groundtruth[-2, 0],
            sample_groundtruth[-1, 1] - sample_groundtruth[-2, 1],
            color="#d33e4c",
            label="Ground Truth",
            alpha=1,
            linewidth=2.5,
            zorder=25,
            head_width=1.0,
        )

# %%
model_unit = HiVT.load_from_checkpoint('/home/alon/Learning/HiVT/lightning_logs/version_26/checkpoints/epoch=63-step=659071.ckpt', parallel=True)
info = model_unit.eval()

# %% [markdown]
# 送入模型的.pt数据格式与内容 cat

# %%
#读取pre-process文件夹内的多个文件并且推理
folder_path = '/home/alon/Learning/HiVT/pre-process'
files = [f for f in os.listdir(folder_path) if f.endswith('.pt')]
for file_name in files:
    file_path = os.path.join(folder_path, file_name)
    print(f"Loading file: {file_name}")
    test_data = torch.load(file_path)

    print('av_index=',test_data['av_index'])
    with torch.no_grad(): 
        y_hat_agent, pi_agent, seq_id ,position_sce= model_unit.predition_unit_batch(test_data,batch_idx=0)
    y_hat_agent = y_hat_agent.permute(0, 1, 2, 3)
    print('y_hat.size = ',y_hat_agent.size())
    pred_traj_np = y_hat_agent.cpu().numpy()
    full_traj = position_sce
    if full_traj.is_cuda:
        full_traj = full_traj.cpu()

    full_traj_np = full_traj.numpy()
    raw_lane_pos = test_data['raw_lane_pos']
    raw_lane_pos_np = raw_lane_pos.cpu().numpy()
    index_agent = test_data['agent_index']
    av_agent = test_data['av_index']
    complete_idx = test_data['complete_samples']
    for i in  complete_idx:
        
        actor_to_show = i
        sample_past_trajectory = full_traj[actor_to_show,:20,:]
        sample_groundtruth = full_traj[actor_to_show,20:,:]
        full_truth = full_traj_np[actor_to_show]
        sample_forecasted_trajectories = [pred_traj_np[actor_to_show][i] for i in range(pred_traj_np.shape[1])]
        # orange red green: past future prediction
        plot_single_vehicle(sample_past_trajectory,sample_groundtruth,sample_forecasted_trajectories,test_data.city,'-.')
        plt.scatter(
        raw_lane_pos_np[:, 0],
        raw_lane_pos_np[:, 1],
        color="#000000",
        label="Lane",
        alpha=0.5,
        s = 1,
        zorder=10)
        plt.axis('equal')
        plt.show()
        plt.close()
# Out:
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_489.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([4, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_279.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([6, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_109.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([3, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_129.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_179.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([4, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_69.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([6, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_159.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([4, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_29.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([7, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_429.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([6, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_329.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([4, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_189.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_229.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_309.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([4, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_469.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_439.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([7, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_479.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_269.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([6, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_19.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([6, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_359.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([4, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_79.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([4, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_49.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([7, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_259.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([6, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_319.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([4, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_139.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_209.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_499.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([4, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_199.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_379.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_289.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_399.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([6, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_339.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([4, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_39.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([7, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_249.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([6, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_149.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_299.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_219.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([4, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_449.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([6, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_99.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([3, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_389.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_349.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([4, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_419.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([6, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_369.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_59.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([6, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_239.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_119.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_459.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([5, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_169.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([4, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_89.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([3, 6, 30, 2])
# Loading file: data_collection_CHERY_E0Y_10034_EVENT_MANUAL_2024-08-21-10-56-27_409.pt
# av_index= 0
# predition_unit_batch is called
# y_hat.size =  torch.Size([6, 6, 30, 2])
